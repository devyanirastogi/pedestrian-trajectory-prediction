# %% [markdown]
# **MID-Based Pedestrian Trajectory Prediction**
#
# Objective
#
# The objective of this project is to predict future pedestrian trajectories using the Motion Indeterminacy Diffusion (MID) framework on the ETH/UCY pedestrian trajectory datasets. The model learns pedestrian movement patterns from past observed trajectories and predicts socially plausible future paths.
#
# Dataset
#
# We used the ETH Dataset pedestrian trajectory dataset, which contains real-world pedestrian movement sequences captured in crowded environments.
#
# For experimentation, the ETH scene was selected for training and evaluation. The raw trajectory files were preprocessed into the Trajectron++ environment format before training.
#
# Preprocessing
#
# The preprocessing pipeline converts raw pedestrian trajectory text files into structured environment representations compatible with the MID framework.
#
# The preprocessing steps included:
#
# Loading pedestrian trajectory coordinates
# Creating scene and node objects
# Computing velocity and acceleration features
# Organizing trajectory sequences into train/validation/test splits
# Saving processed environment files in .pkl format
#
# The generated files were used directly by the MID training pipeline.
#
# Model
#
# The project uses the Motion Indeterminacy Diffusion (MID) model for trajectory prediction. MID combines:
#
# Transformer-based trajectory encoding
# Diffusion probabilistic modeling
# Social trajectory representation
#
# The diffusion process enables the model to generate multiple socially consistent future pedestrian trajectories while accounting for uncertainty in motion prediction.
#
# Training Configuration
#
# The model was trained on the ETH scene using the following configuration:
#
# Epochs: 20
# Batch Size: 128
# Diffusion Steps: 50
# Learning Rate: 1e-3
# Encoder Dimension: 256
# Device: NVIDIA T4 GPU
#
# The training process was performed in Google Colab using GPU acceleration.

# %%
# !git clone https://github.com/devyanirastogi/pedestrian-trajectory-prediction.git
# Out:
# Cloning into 'pedestrian-trajectory-prediction'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 155 (delta 25), reused 141 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (155/155), 5.62 MiB | 18.62 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("Using CPU")
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# %pip install ncls
# Out:
# Collecting ncls
#   Downloading ncls-0.0.70-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ncls) (2.0.2)
# Downloading ncls-0.0.70-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 85.4 MB/s eta 0:00:00
# Installing collected packages: ncls
# Successfully installed ncls-0.0.70

# %%
"""
preprocess_ethucy.py
====================
From-scratch preprocessing of ETH/UCY data into the Environment/Scene/Node
format that Trajectron++ (and therefore MID) expects.

This script does NOT copy-paste from the MID repo. Instead, it rebuilds the
preprocessing logic from first principles, with comments explaining what each
step does and WHY the Trajectron++ encoder needs it.

Dependencies:
    pip install numpy pandas dill

    These are also needed by the environment/ module at import time:
    pip install torch ncls orjson

Overview of what this script produces:
    ┌─────────────────────────────────────────────────────┐
    │ Environment                                         │
    │   - standardization config (mean/std per feature)   │
    │   - attention_radius = 3.0m (who counts as nearby)  │
    │   - node types: just PEDESTRIAN                     │
    │   - scenes: [Scene, Scene, ...]                     │
    │                                                     │
    │   ┌─────────────────────────────────────────────┐   │
    │   │ Scene  (one per .txt file)                   │   │
    │   │   - timesteps: total frames in this file     │   │
    │   │   - dt: 0.4s between frames                  │   │
    │   │   - nodes: [Node, Node, ...]                 │   │
    │   │   - augmented: 24 rotated copies (train)     │   │
    │   │                                              │   │
    │   │   ┌─────────────────────────────────────┐    │   │
    │   │   │ Node  (one per pedestrian)           │    │   │
    │   │   │   - data: (T, 6) array               │    │   │
    │   │   │     cols: pos_x, pos_y,              │    │   │
    │   │   │           vel_x, vel_y,              │    │   │
    │   │   │           acc_x, acc_y               │    │   │
    │   │   │   - first_timestep: when they appear │    │   │
    │   │   │   - type: PEDESTRIAN                 │    │   │
    │   │   └─────────────────────────────────────┘    │   │
    │   └─────────────────────────────────────────────┘   │
    └─────────────────────────────────────────────────────┘

Why this format?
    Trajectron++ (the encoder) expects Scene objects so it can:
    1. Look up which pedestrians are present at each timestep
    2. Compute pairwise distances to build the social interaction graph
       (edges between pedestrians within the attention_radius)
    3. Access position/velocity/acceleration features per node
    4. Standardize features using the Environment's config
"""

import os
import sys
import glob
import numpy as np
import pandas as pd
import dill

# Add project root (parent of notebooks/) to path so `environment` is importable
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from environment import Environment, Scene, Node, derivative_of


# ─────────────────────────────────────────────────────────────────────
# Configuration
# ─────────────────────────────────────────────────────────────────────
#RAW_DATA_ROOT = "/content/drive/MyDrive/pedestrian-ddpm/raw_data" ##
RAW_DATA_ROOT = os.path.join(PROJECT_ROOT, "raw_data")  # directory containing eth/, hotel/, etc.
OUTPUT_DIR = os.path.join(PROJECT_ROOT, "processed_data")
SCENES = ["eth", "hotel", "univ", "zara1", "zara2"]
SPLITS = ["train", "val", "test"]

FRAME_SKIP = 10    # raw data uses frame IDs 0, 10, 20, ... → normalize to 0, 1, 2, ...
DT = 0.4           # seconds between normalized frames

# Standardization parameters for the Trajectron++ encoder.
# These define how each feature is normalized before being fed to the model.
# Position has std=1 (used as-is), velocity has std=2 (halved), acceleration std=1.
# Mean is 0 for all — we already zero-center positions per scene file.
STANDARDIZATION = {
    "PEDESTRIAN": {
        "position":     {"x": {"mean": 0, "std": 1}, "y": {"mean": 0, "std": 1}},
        "velocity":     {"x": {"mean": 0, "std": 2}, "y": {"mean": 0, "std": 2}},
        "acceleration": {"x": {"mean": 0, "std": 1}, "y": {"mean": 0, "std": 1}},
    }
}

# Social interaction radius: two pedestrians within 3 meters of each other
# get an edge in the scene graph. This is what the GNN encoder uses.
ATTENTION_RADIUS = 3.0

# Training augmentation: rotate trajectories by these angles
AUGMENT_ANGLES = np.arange(0, 360, 15)  # 24 rotations: 0°, 15°, 30°, ..., 345°


# ─────────────────────────────────────────────────────────────────────
# Helper: compute derivatives via finite differences
# ─────────────────────────────────────────────────────────────────────
def compute_velocity(positions, dt):
    """
    Compute velocity from positions using numpy gradient (central differences).

    This is what Trajectron++ expects: not just (x[t] - x[t-1]) / dt,
    but np.gradient which uses central differences for interior points
    and one-sided differences at the boundaries. This gives smoother
    velocity estimates.

    Args:
        positions: 1D array of x or y coordinates
        dt: time step between frames (0.4s)

    Returns:
        velocity: 1D array same length as positions
    """
    if len(positions[~np.isnan(positions)]) < 2:
        return np.zeros_like(positions)

    vel = np.full_like(positions, np.nan)
    valid = ~np.isnan(positions)
    vel[valid] = np.gradient(positions[valid], dt)
    return vel


# ─────────────────────────────────────────────────────────────────────
# Helper: the 6-column DataFrame that Node expects
# ─────────────────────────────────────────────────────────────────────
# Node stores data as a DoubleHeaderNumpyArray with this column structure:
#   (position, x), (position, y), (velocity, x), (velocity, y), (acceleration, x), (acceleration, y)
# We build it as a pandas DataFrame with a MultiIndex on columns,
# then Node.__init__ converts it internally.

DATA_COLUMNS = pd.MultiIndex.from_product(
    [["position", "velocity", "acceleration"], ["x", "y"]]
)


def build_node_dataframe(x_positions, y_positions, dt):
    """
    From raw x,y position arrays, compute all 6 features and return
    the DataFrame that Node expects.

    Features:
        position:     (x, y)  — the raw coordinates
        velocity:     (vx, vy) — first derivative of position
        acceleration: (ax, ay) — second derivative (first derivative of velocity)

    Args:
        x_positions: 1D array of x coordinates for this pedestrian
        y_positions: 1D array of y coordinates
        dt: time step (0.4s)

    Returns:
        pd.DataFrame with 6 columns and MultiIndex headers
    """
    vx = compute_velocity(x_positions, dt)
    vy = compute_velocity(y_positions, dt)
    ax = compute_velocity(vx, dt)  # acceleration = derivative of velocity
    ay = compute_velocity(vy, dt)

    return pd.DataFrame(
        {
            ("position", "x"):     x_positions,
            ("position", "y"):     y_positions,
            ("velocity", "x"):     vx,
            ("velocity", "y"):     vy,
            ("acceleration", "x"): ax,
            ("acceleration", "y"): ay,
        },
        columns=DATA_COLUMNS,
    )


# ─────────────────────────────────────────────────────────────────────
# Helper: rotation augmentation
# ─────────────────────────────────────────────────────────────────────
def rotate_scene(scene, angle_degrees):
    """
    Create a copy of the scene with all trajectories rotated.

    This is a data augmentation trick: since the model should be invariant
    to the absolute orientation of trajectories, we can multiply our
    training data by 24x by rotating everything by 0°, 15°, 30°, ..., 345°.

    Importantly, after rotating positions we RECOMPUTE velocity and
    acceleration from the rotated positions. You can't just rotate the
    velocities because np.gradient depends on the actual coordinate values.
    (Well, mathematically you can rotate velocities too, but recomputing
    is safer and matches what the original code does.)
    """
    angle_rad = angle_degrees * np.pi / 180
    cos_a = np.cos(angle_rad)
    sin_a = np.sin(angle_rad)
    rotation_matrix = np.array([[cos_a, -sin_a],
                                 [sin_a,  cos_a]])

    augmented_scene = Scene(
        timesteps=scene.timesteps,
        dt=scene.dt,
        name=scene.name,
    )

    for node in scene.nodes:
        # Extract original x, y positions
        x_orig = node.data.position.x.copy()
        y_orig = node.data.position.y.copy()

        # Apply 2D rotation: [x', y'] = R @ [x, y]
        coords = np.stack([x_orig, y_orig], axis=0)  # (2, T)
        rotated = rotation_matrix @ coords             # (2, T)
        x_rot, y_rot = rotated[0], rotated[1]

        # Recompute derivatives from rotated positions
        node_df = build_node_dataframe(x_rot, y_rot, scene.dt)

        new_node = Node(
            node_type=node.type,
            node_id=node.id,
            data=node_df,
            first_timestep=node.first_timestep,
        )
        augmented_scene.nodes.append(new_node)

    return augmented_scene


def pick_random_augmentation(scene):
    """Called at training time to randomly select one of the 24 rotations."""
    scene_aug = np.random.choice(scene.augmented)
    scene_aug.temporal_scene_graph = scene.temporal_scene_graph
    return scene_aug


# ─────────────────────────────────────────────────────────────────────
# Core: process one .txt file into a Scene
# ─────────────────────────────────────────────────────────────────────
def txt_to_scene(filepath, scene_name, split, env):
    """
    Read a raw trajectory .txt file and convert it to a Scene object.

    Processing steps:
        1. Parse the 4-column TSV: frame_id, pedestrian_id, x, y
        2. Normalize frame IDs (0, 10, 20, ... → 0, 1, 2, ...)
        3. Apply the ETH test set scaling quirk (0.6x)
        4. Zero-center all positions (subtract global mean of x and y)
        5. For each pedestrian, compute velocity and acceleration
        6. Wrap each pedestrian as a Node, collect into a Scene
        7. For training scenes, pre-compute 24 rotation augmentations

    Args:
        filepath: path to the .txt file
        scene_name: e.g. "eth", "hotel"
        split: "train", "val", or "test"
        env: the Environment object (needed for node type reference)

    Returns:
        Scene object
    """
    # ── Step 1: Parse raw file ──
    # Format: frame_id <tab> pedestrian_id <tab> x <tab> y
    df = pd.read_csv(filepath, sep="\t", header=None)
    df.columns = ["frame", "ped_id", "x", "y"]
    df["frame"] = df["frame"].astype(int)
    df["ped_id"] = df["ped_id"].astype(int)

    # ── Step 2: Normalize frame IDs ──
    # Raw frames are 0, 10, 20, 30, ... (every 10th video frame)
    # We normalize to 0, 1, 2, 3, ... so each step = 0.4 seconds
    df["frame"] = df["frame"] // FRAME_SKIP

    # Shift so the first frame in this file is 0
    df["frame"] -= df["frame"].min()

    df = df.sort_values("frame").reset_index(drop=True)

    # ── Step 3: ETH test set scaling ──
    # The ETH test set (biwi_eth.txt) uses a different coordinate system
    # than the training data. The standard fix is to scale by 0.6.
    # This is a known quirk in the ETH/UCY benchmark.
    if scene_name == "eth" and split == "test":
        df["x"] *= 0.6
        df["y"] *= 0.6

    # ── Step 4: Zero-center positions ──
    # We subtract the mean x and y across ALL pedestrians and ALL frames
    # in this file. This is per-file centering, not per-pedestrian.
    # It roughly centers the scene around the origin.
    df["x"] -= df["x"].mean()
    df["y"] -= df["y"].mean()

    # ── Step 5 & 6: Build Nodes ──
    total_frames = df["frame"].max() + 1

    scene = Scene(
        timesteps=total_frames,
        dt=DT,
        name=f"{scene_name}_{split}",
        aug_func=pick_random_augmentation if split == "train" else None,
    )

    for ped_id, ped_df in df.groupby("ped_id"):
        positions = ped_df[["x", "y"]].values  # (T_ped, 2)

        # Skip pedestrians with fewer than 2 observations
        # (can't compute velocity with just 1 point)
        if positions.shape[0] < 2:
            continue

        first_frame = ped_df["frame"].iloc[0]

        # Build the 6-feature DataFrame
        node_df = build_node_dataframe(
            x_positions=positions[:, 0],
            y_positions=positions[:, 1],
            dt=DT,
        )

        # Create Node
        node = Node(
            node_type=env.NodeType.PEDESTRIAN,
            node_id=str(ped_id),
            data=node_df,
        )
        node.first_timestep = first_frame

        scene.nodes.append(node)

    # ── Step 7: Augmentation (training only) ──
    # Pre-compute 24 rotated versions of the scene.
    # At training time, pick_random_augmentation() selects one at random.
    if split == "train":
        scene.augmented = [
            rotate_scene(scene, angle) for angle in AUGMENT_ANGLES
        ]

    return scene


# ─────────────────────────────────────────────────────────────────────
# Main: process all scenes and splits
# ─────────────────────────────────────────────────────────────────────
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    print("=" * 60)
    print("Preprocessing ETH/UCY → Trajectron++ format")
    print("=" * 60)

    for scene_name in SCENES:
        for split in SPLITS:
            print(f"\n── {scene_name.upper()} / {split} ──")

            # Create a fresh Environment for this split
            env = Environment(
                node_type_list=["PEDESTRIAN"],
                standardization=STANDARDIZATION,
            )
            env.attention_radius = {
                (env.NodeType.PEDESTRIAN, env.NodeType.PEDESTRIAN): ATTENTION_RADIUS,
            }

            # Find all .txt files for this scene/split
            split_dir = os.path.join(RAW_DATA_ROOT, scene_name, split)
            txt_files = sorted(glob.glob(os.path.join(split_dir, "*.txt")))

            if not txt_files:
                print(f"  WARNING: no .txt files in {split_dir}")
                continue

            scenes = []
            for fpath in txt_files:
                fname = os.path.basename(fpath)
                scene = txt_to_scene(fpath, scene_name, split, env)
                print(f"  {fname}: {len(scene.nodes)} pedestrians, "
                      f"{scene.timesteps} frames, "
                      f"{scene.duration():.1f}s duration")
                scenes.append(scene)

            env.scenes = scenes

            # Save as .pkl
            out_path = os.path.join(OUTPUT_DIR, f"{scene_name}_{split}.pkl")
            with open(out_path, "wb") as f:
                dill.dump(env, f, protocol=dill.HIGHEST_PROTOCOL)
            print(f"  → Saved to {out_path}")

    print("\n" + "=" * 60)
    print("Done! Files are in:", OUTPUT_DIR)
    print("=" * 60)
    print("\nTo train MID:")
    print("  python main.py --config configs/baseline.yaml --dataset eth")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Preprocessing ETH/UCY → Trajectron++ format
# ============================================================
#
# ── ETH / train ──
#   biwi_hotel_train.txt: 310 pedestrians, 1440 frames, 576.0s duration
#   crowds_zara01_train.txt: 125 pedestrians, 711 frames, 284.4s duration
#   crowds_zara02_train.txt: 171 pedestrians, 841 frames, 336.4s duration
#   crowds_zara03_train.txt: 105 pedestrians, 603 frames, 241.2s duration
#   students001_train.txt: 373 pedestrians, 355 frames, 142.0s duration
#   students003_train.txt: 364 pedestrians, 432 frames, 172.8s duration
#   uni_examples_train.txt: 96 pedestrians, 594 frames, 237.6s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/eth_train.pkl
#
# ── ETH / val ──
#   biwi_hotel_val.txt: 81 pedestrians, 367 frames, 146.8s duration
#   crowds_zara01_val.txt: 28 pedestrians, 191 frames, 76.4s duration
#   crowds_zara02_val.txt: 47 pedestrians, 211 frames, 84.4s duration
#   crowds_zara03_val.txt: 33 pedestrians, 151 frames, 60.4s duration
#   students001_val.txt: 95 pedestrians, 89 frames, 35.6s duration
#   students003_val.txt: 92 pedestrians, 109 frames, 43.6s duration
#   uni_examples_val.txt: 24 pedestrians, 148 frames, 59.2s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/eth_val.pkl
#
# ── ETH / test ──
#   biwi_eth.txt: 360 pedestrians, 1161 frames, 464.4s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/eth_test.pkl
#
# ── HOTEL / train ──
#   biwi_eth_train.txt: 250 pedestrians, 946 frames, 378.4s duration
#   crowds_zara01_train.txt: 125 pedestrians, 711 frames, 284.4s duration
#   crowds_zara02_train.txt: 171 pedestrians, 841 frames, 336.4s duration
#   crowds_zara03_train.txt: 105 pedestrians, 603 frames, 241.2s duration
#   students001_train.txt: 373 pedestrians, 355 frames, 142.0s duration
#   students003_train.txt: 364 pedestrians, 432 frames, 172.8s duration
#   uni_examples_train.txt: 96 pedestrians, 594 frames, 237.6s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/hotel_train.pkl
#
# ── HOTEL / val ──
#   biwi_eth_val.txt: 120 pedestrians, 215 frames, 86.0s duration
#   crowds_zara01_val.txt: 28 pedestrians, 191 frames, 76.4s duration
#   crowds_zara02_val.txt: 47 pedestrians, 211 frames, 84.4s duration
#   crowds_zara03_val.txt: 33 pedestrians, 151 frames, 60.4s duration
#   students001_val.txt: 95 pedestrians, 89 frames, 35.6s duration
#   students003_val.txt: 92 pedestrians, 109 frames, 43.6s duration
#   uni_examples_val.txt: 24 pedestrians, 148 frames, 59.2s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/hotel_val.pkl
#
# ── HOTEL / test ──
#   biwi_hotel.txt: 389 pedestrians, 1807 frames, 722.8s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/hotel_test.pkl
#
# ── UNIV / train ──
#   biwi_eth_train.txt: 250 pedestrians, 946 frames, 378.4s duration
#   biwi_hotel_train.txt: 310 pedestrians, 1440 frames, 576.0s duration
#   crowds_zara01_train.txt: 125 pedestrians, 711 frames, 284.4s duration
#   crowds_zara02_train.txt: 171 pedestrians, 841 frames, 336.4s duration
#   crowds_zara03_train.txt: 105 pedestrians, 603 frames, 241.2s duration
#   uni_examples_train.txt: 96 pedestrians, 594 frames, 237.6s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/univ_train.pkl
#
# ── UNIV / val ──
#   biwi_eth_val.txt: 120 pedestrians, 215 frames, 86.0s duration
#   biwi_hotel_val.txt: 81 pedestrians, 367 frames, 146.8s duration
#   crowds_zara01_val.txt: 28 pedestrians, 191 frames, 76.4s duration
#   crowds_zara02_val.txt: 47 pedestrians, 211 frames, 84.4s duration
#   crowds_zara03_val.txt: 33 pedestrians, 151 frames, 60.4s duration
#   uni_examples_val.txt: 24 pedestrians, 148 frames, 59.2s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/univ_val.pkl
#
# ── UNIV / test ──
#   students001.txt: 415 pedestrians, 444 frames, 177.6s duration
#   students003.txt: 434 pedestrians, 541 frames, 216.4s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/univ_test.pkl
#
# ── ZARA1 / train ──
#   biwi_eth_train.txt: 250 pedestrians, 946 frames, 378.4s duration
#   biwi_hotel_train.txt: 310 pedestrians, 1440 frames, 576.0s duration
#   crowds_zara02_train.txt: 171 pedestrians, 841 frames, 336.4s duration
#   crowds_zara03_train.txt: 105 pedestrians, 603 frames, 241.2s duration
#   students001_train.txt: 373 pedestrians, 355 frames, 142.0s duration
#   students003_train.txt: 364 pedestrians, 432 frames, 172.8s duration
#   uni_examples_train.txt: 96 pedestrians, 594 frames, 237.6s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/zara1_train.pkl
#
# ── ZARA1 / val ──
#   biwi_eth_val.txt: 120 pedestrians, 215 frames, 86.0s duration
#   biwi_hotel_val.txt: 81 pedestrians, 367 frames, 146.8s duration
#   crowds_zara02_val.txt: 47 pedestrians, 211 frames, 84.4s duration
#   crowds_zara03_val.txt: 33 pedestrians, 151 frames, 60.4s duration
#   students001_val.txt: 95 pedestrians, 89 frames, 35.6s duration
#   students003_val.txt: 92 pedestrians, 109 frames, 43.6s duration
#   uni_examples_val.txt: 24 pedestrians, 148 frames, 59.2s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/zara1_val.pkl
#
# ── ZARA1 / test ──
#   crowds_zara01.txt: 148 pedestrians, 902 frames, 360.8s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/zara1_test.pkl
#
# ── ZARA2 / train ──
#   biwi_eth_train.txt: 250 pedestrians, 946 frames, 378.4s duration
#   biwi_hotel_train.txt: 310 pedestrians, 1440 frames, 576.0s duration
#   crowds_zara01_train.txt: 125 pedestrians, 711 frames, 284.4s duration
#   crowds_zara03_train.txt: 105 pedestrians, 603 frames, 241.2s duration
#   students001_train.txt: 373 pedestrians, 355 frames, 142.0s duration
#   students003_train.txt: 364 pedestrians, 432 frames, 172.8s duration
#   uni_examples_train.txt: 96 pedestrians, 594 frames, 237.6s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/zara2_train.pkl
#
# ── ZARA2 / val ──
#   biwi_eth_val.txt: 120 pedestrians, 215 frames, 86.0s duration
#   biwi_hotel_val.txt: 81 pedestrians, 367 frames, 146.8s duration
#   crowds_zara01_val.txt: 28 pedestrians, 191 frames, 76.4s duration
#   crowds_zara03_val.txt: 33 pedestrians, 151 frames, 60.4s duration
#   students001_val.txt: 95 pedestrians, 89 frames, 35.6s duration
#   students003_val.txt: 92 pedestrians, 109 frames, 43.6s duration
#   uni_examples_val.txt: 24 pedestrians, 148 frames, 59.2s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/zara2_val.pkl
#
# ── ZARA2 / test ──
#   crowds_zara02.txt: 204 pedestrians, 1052 frames, 420.8s duration
#   → Saved to /content/pedestrian-trajectory-prediction/processed_data/zara2_test.pkl
#
# ============================================================
# Done! Files are in: /content/pedestrian-trajectory-prediction/processed_data
# ============================================================
#
# To train MID:
#   python main.py --config configs/baseline.yaml --dataset eth

# %%
import os
os.chdir("/content/pedestrian-trajectory-prediction/notebooks")

print(os.getcwd())
# Out:
# /content/pedestrian-trajectory-prediction/notebooks

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
# Out:
# /content/pedestrian-trajectory-prediction

# %%
import json

path = "/content/pedestrian-trajectory-prediction/notebooks/train.ipynb"

with open(path, "r") as f:
    nb = json.load(f)

for cell in nb["cells"]:
    if cell["cell_type"] == "code":
        src = "".join(cell["source"])

        src = src.replace("EPOCHS = 90", "EPOCHS = 20")
        src = src.replace("BATCH_SIZE = 64", "BATCH_SIZE = 128")
        src = src.replace("NUM_DIFFUSION_STEPS = 100", "NUM_DIFFUSION_STEPS = 50")

        cell["source"] = src.splitlines(keepends=True)

with open(path, "w") as f:
    json.dump(nb, f)

print("Updated to 20 epochs.")
# Out:
# Updated to 20 epochs.

# %%
with open(path, "r") as f:
    content = f.read()

print("EPOCHS = 20" in content)
print("BATCH_SIZE = 128" in content)
print("NUM_DIFFUSION_STEPS = 50" in content)
# Out:
# True
# True
# True

# %%
# %run -i /content/pedestrian-trajectory-prediction/notebooks/train.ipynb
# Out:
# Device: cuda
# Loaded /content/pedestrian-trajectory-prediction/processed_data/eth_train.pkl
#   scenes: 7
#   total nodes: 1544
#   attention_radius: {(PEDESTRIAN, PEDESTRIAN): 3.0}
#
# Node type: PEDESTRIAN
# Batches per epoch: 296
# Encoder constructed with 608,212 parameters
# Total params:     7,548,644
# Trainable params: 7,548,644
# /content/pedestrian-trajectory-prediction/mid_model/diffusion.py:168: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=tf_layer)
# Smoke-test loss: 1.0136
# Epoch 1/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 1: avg loss = 0.2456  (295.2s)
# Epoch 2/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 2: avg loss = 0.1791  (289.9s)
# Epoch 3/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 3: avg loss = 0.1706  (297.1s)
# Epoch 4/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 4: avg loss = 0.1646  (297.5s)
# Epoch 5/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 5: avg loss = 0.1578  (302.0s)
# Epoch 6/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 6: avg loss = 0.1502  (298.5s)
# Epoch 7/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 7: avg loss = 0.1486  (294.4s)
# Epoch 8/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 8: avg loss = 0.1461  (297.5s)
# Epoch 9/20:   0%|                                                           | 0/296 [00:00<?, ?it/s]
#   epoch 9: avg loss = 0.1447  (296.5s)
# Epoch 10/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 10: avg loss = 0.1439  (293.8s)
# Epoch 11/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 11: avg loss = 0.1421  (293.0s)
# Epoch 12/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 12: avg loss = 0.1411  (288.8s)
# Epoch 13/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 13: avg loss = 0.1397  (296.4s)
# Epoch 14/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 14: avg loss = 0.1400  (293.3s)
# Epoch 15/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 15: avg loss = 0.1399  (297.9s)
# Epoch 16/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 16: avg loss = 0.1396  (296.2s)
# Epoch 17/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 17: avg loss = 0.1399  (300.8s)
# Epoch 18/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 18: avg loss = 0.1382  (300.7s)
# Epoch 19/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 19: avg loss = 0.1379  (297.6s)
# Epoch 20/20:   0%|                                                          | 0/296 [00:00<?, ?it/s]
#   epoch 20: avg loss = 0.1360  (299.7s)
# Saved checkpoint to ../checkpoints/mid_eth.pt

# %%
import os
os.listdir("/content/pedestrian-trajectory-prediction/checkpoints")
# Out:
# ['mid_eth.pt']

# %%
# !zip -r project_backup.zip /content/pedestrian-trajectory-prediction
# Out:
#   adding: content/pedestrian-trajectory-prediction/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/zara2_train.pkl (deflated 25%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/zara2_test.pkl (deflated 36%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/zara1_test.pkl (deflated 29%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/eth_val.pkl (deflated 37%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/zara1_val.pkl (deflated 43%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/eth_train.pkl (deflated 23%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/zara1_train.pkl (deflated 25%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/hotel_train.pkl (deflated 22%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/hotel_val.pkl (deflated 38%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/univ_val.pkl (deflated 50%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/univ_test.pkl (deflated 27%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/univ_train.pkl (deflated 32%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/hotel_test.pkl (deflated 74%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/eth_test.pkl (deflated 64%)
#   adding: content/pedestrian-trajectory-prediction/processed_data/zara2_val.pkl (deflated 42%)
#   adding: content/pedestrian-trajectory-prediction/models/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/common.py (deflated 69%)
#   adding: content/pedestrian-trajectory-prediction/models/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/__pycache__/trajectron.cpython-312.pyc (deflated 56%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/__init__.py (deflated 13%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/__pycache__/mgcvae.cpython-312.pyc (deflated 65%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/__pycache__/__init__.cpython-312.pyc (deflated 15%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/__pycache__/model_utils.cpython-312.pyc (deflated 47%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/__init__.py (deflated 39%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/__pycache__/dynamic.cpython-312.pyc (deflated 52%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/__pycache__/__init__.cpython-312.pyc (deflated 20%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/__pycache__/single_integrator.cpython-312.pyc (deflated 56%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/single_integrator.py (deflated 71%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/dynamic.py (deflated 65%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/linear.py (deflated 44%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/dynamics/unicycle.py (deflated 82%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__init__.py (deflated 42%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/additive_attention.py (deflated 79%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/additive_attention.cpython-312.pyc (deflated 51%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/__init__.cpython-312.pyc (deflated 27%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/discrete_latent.cpython-312.pyc (deflated 56%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/gmm2d.cpython-312.pyc (deflated 55%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/map_encoder.cpython-312.pyc (deflated 40%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/__pycache__/n_pair_loss.cpython-312.pyc (deflated 47%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/graph_attention.py (deflated 69%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/n_pair_loss.py (deflated 66%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/discrete_latent.py (deflated 73%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/map_encoder.py (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/components/gmm2d.py (deflated 71%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/mgcvae.py (deflated 85%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/utils/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/utils/scene_graph.py (deflated 82%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/trajectron.py (deflated 78%)
#   adding: content/pedestrian-trajectory-prediction/models/encoders/model_utils.py (deflated 62%)
#   adding: content/pedestrian-trajectory-prediction/models/trajectron.py (deflated 80%)
#   adding: content/pedestrian-trajectory-prediction/models/diffusion.py (deflated 76%)
#   adding: content/pedestrian-trajectory-prediction/models/transformer.py (deflated 79%)
#   adding: content/pedestrian-trajectory-prediction/models/autoencoder.py (deflated 63%)
#   adding: content/pedestrian-trajectory-prediction/environment/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/environment/__init__.py (deflated 47%)
#   adding: content/pedestrian-trajectory-prediction/environment/node_type.py (deflated 69%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/__init__.cpython-312.pyc (deflated 28%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/data_utils.cpython-312.pyc (deflated 45%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/node_type.cpython-312.pyc (deflated 48%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/scene.cpython-312.pyc (deflated 53%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/environment.cpython-312.pyc (deflated 50%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/node.cpython-312.pyc (deflated 56%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/scene_graph.cpython-312.pyc (deflated 63%)
#   adding: content/pedestrian-trajectory-prediction/environment/__pycache__/data_structures.cpython-312.pyc (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/environment/node.py (deflated 77%)
#   adding: content/pedestrian-trajectory-prediction/environment/environment.py (deflated 76%)
#   adding: content/pedestrian-trajectory-prediction/environment/data_utils.py (deflated 61%)
#   adding: content/pedestrian-trajectory-prediction/environment/data_structures.py (deflated 77%)
#   adding: content/pedestrian-trajectory-prediction/environment/scene_graph.py (deflated 82%)
#   adding: content/pedestrian-trajectory-prediction/environment/scene.py (deflated 77%)
#   adding: content/pedestrian-trajectory-prediction/dataset/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/dataset/preprocessing.py (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/dataset/__init__.py (deflated 30%)
#   adding: content/pedestrian-trajectory-prediction/dataset/dataset.py (deflated 74%)
#   adding: content/pedestrian-trajectory-prediction/dataset/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/dataset/__pycache__/dataset.cpython-312.pyc (deflated 49%)
#   adding: content/pedestrian-trajectory-prediction/dataset/__pycache__/__init__.cpython-312.pyc (deflated 24%)
#   adding: content/pedestrian-trajectory-prediction/dataset/__pycache__/preprocessing.cpython-312.pyc (deflated 51%)
#   adding: content/pedestrian-trajectory-prediction/dataset/homography_warper.py (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__init__.py (deflated 47%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/dataset.py (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/common.py (deflated 57%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/hypers.py (deflated 62%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/dataset.cpython-312.pyc (deflated 46%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/eval.cpython-312.pyc (deflated 48%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/common.cpython-312.pyc (deflated 48%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/loo.cpython-312.pyc (deflated 42%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/__init__.cpython-312.pyc (deflated 30%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/hypers.cpython-312.pyc (deflated 41%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/autoencoder.cpython-312.pyc (deflated 49%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/cvae.cpython-312.pyc (deflated 52%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/cvae_autoencoder.cpython-312.pyc (deflated 45%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/__pycache__/diffusion.cpython-312.pyc (deflated 50%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/loo.py (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/eval.py (deflated 65%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/cvae.py (deflated 70%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/cvae_autoencoder.py (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/diffusion.py (deflated 69%)
#   adding: content/pedestrian-trajectory-prediction/mid_model/autoencoder.py (deflated 62%)
#   adding: content/pedestrian-trajectory-prediction/checkpoints/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/checkpoints/mid_eth.pt (deflated 7%)
#   adding: content/pedestrian-trajectory-prediction/utils/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/utils/transform.py (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/utils/dataset.py (deflated 66%)
#   adding: content/pedestrian-trajectory-prediction/utils/data.py (deflated 68%)
#   adding: content/pedestrian-trajectory-prediction/utils/__pycache__/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/utils/__pycache__/model_registrar.cpython-312.pyc (deflated 54%)
#   adding: content/pedestrian-trajectory-prediction/utils/argument_parser.py (deflated 81%)
#   adding: content/pedestrian-trajectory-prediction/utils/misc.py (deflated 70%)
#   adding: content/pedestrian-trajectory-prediction/utils/model_registrar.py (deflated 72%)
#   adding: content/pedestrian-trajectory-prediction/utils/trajectron_hypers.py (deflated 65%)
#   adding: content/pedestrian-trajectory-prediction/README.md (deflated 54%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/biwi_eth_train.txt (deflated 70%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/crowds_zara03_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/uni_examples_train.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/crowds_zara01_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/students003_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/students001_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/train/biwi_hotel_train.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/students001_val.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/uni_examples_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/students003_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/biwi_hotel_val.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/crowds_zara01_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/crowds_zara03_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/val/biwi_eth_val.txt (deflated 71%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/test/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara2/test/crowds_zara02.txt (deflated 61%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/biwi_eth_train.txt (deflated 70%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/crowds_zara03_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/uni_examples_train.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/crowds_zara01_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/crowds_zara02_train.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/students003_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/train/students001_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/students001_val.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/uni_examples_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/students003_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/crowds_zara01_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/crowds_zara03_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/crowds_zara02_val.txt (deflated 63%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/val/biwi_eth_val.txt (deflated 71%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/test/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/hotel/test/biwi_hotel.txt (deflated 74%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/biwi_eth_train.txt (deflated 70%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/crowds_zara03_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/uni_examples_train.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/crowds_zara02_train.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/students003_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/students001_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/train/biwi_hotel_train.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/students001_val.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/uni_examples_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/students003_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/biwi_hotel_val.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/crowds_zara03_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/crowds_zara02_val.txt (deflated 63%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/val/biwi_eth_val.txt (deflated 71%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/test/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/zara1/test/crowds_zara01.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/biwi_eth_train.txt (deflated 70%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/crowds_zara03_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/uni_examples_train.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/crowds_zara01_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/crowds_zara02_train.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/train/biwi_hotel_train.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/uni_examples_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/biwi_hotel_val.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/crowds_zara01_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/crowds_zara03_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/crowds_zara02_val.txt (deflated 63%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/val/biwi_eth_val.txt (deflated 71%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/test/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/test/students003.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/univ/test/students001.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/stanford/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/stanford/train_trajnet.pkl (deflated 92%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/stanford/test_trajnet.pkl (deflated 92%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/crowds_zara03_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/uni_examples_train.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/crowds_zara01_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/crowds_zara02_train.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/students003_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/students001_train.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/train/biwi_hotel_train.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/students001_val.txt (deflated 60%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/uni_examples_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/students003_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/biwi_hotel_val.txt (deflated 75%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/crowds_zara01_val.txt (deflated 58%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/crowds_zara03_val.txt (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/val/crowds_zara02_val.txt (deflated 63%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/test/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/raw_data/eth/test/biwi_eth.txt (deflated 69%)
#   adding: content/pedestrian-trajectory-prediction/.gitignore (deflated 23%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/07_density_over_time.png (deflated 5%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/06_start_end_points.png (deflated 3%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/08_nn_distance.png (deflated 4%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/05_sample_trajectories.png (deflated 1%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/01_overview.png (deflated 14%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/02_trajectory_lengths.png (deflated 10%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/03_speed_distribution.png (deflated 4%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/figures/04_position_heatmaps.png (deflated 1%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/train.ipynb (deflated 82%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/train_cvae.ipynb (deflated 77%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/overfit_underfit.ipynb (deflated 72%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/eval.ipynb (deflated 42%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/pre-process.ipynb (deflated 79%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/ETH_UCY_EDA.ipynb (deflated 27%)
#   adding: content/pedestrian-trajectory-prediction/notebooks/load_splits.ipynb (deflated 82%)
#   adding: content/pedestrian-trajectory-prediction/.git/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/branches/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/index (deflated 65%)
#   adding: content/pedestrian-trajectory-prediction/.git/HEAD (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/HEAD (deflated 29%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/refs/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/refs/remotes/origin/HEAD (deflated 29%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/refs/heads/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/logs/refs/heads/main (deflated 29%)
#   adding: content/pedestrian-trajectory-prediction/.git/description (deflated 14%)
#   adding: content/pedestrian-trajectory-prediction/.git/objects/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/objects/pack/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/objects/pack/pack-86a74f2f12d78c3274843e8949761e4f9390fb77.idx (deflated 14%)
#   adding: content/pedestrian-trajectory-prediction/.git/objects/pack/pack-86a74f2f12d78c3274843e8949761e4f9390fb77.pack (deflated 1%)
#   adding: content/pedestrian-trajectory-prediction/.git/objects/info/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/update.sample (deflated 68%)
#   adding: content/pedestrian-trajectory-prediction/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/remotes/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/heads/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/heads/main (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/refs/tags/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/packed-refs (deflated 12%)
#   adding: content/pedestrian-trajectory-prediction/.git/config (deflated 34%)
#   adding: content/pedestrian-trajectory-prediction/.git/info/ (stored 0%)
#   adding: content/pedestrian-trajectory-prediction/.git/info/exclude (deflated 28%)

# %% [markdown]
# Results
#
# The model successfully completed training and produced a saved checkpoint:
#
# mid_eth.pt
#
# The training loss consistently decreased during training, indicating successful learning of pedestrian movement dynamics.
#
# Final observed training loss:
#
# ~0.136
# Conclusion
#
# This project successfully implemented and trained the MID pedestrian trajectory prediction framework on the ETH dataset. The experiments demonstrated that diffusion-based trajectory modeling can effectively learn pedestrian movement behavior and generate plausible future trajectory predictions.
